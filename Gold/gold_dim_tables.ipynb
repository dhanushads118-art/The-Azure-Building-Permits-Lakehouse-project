# %%
# %sql
DROP TABLE IF EXISTS la_lakehouse.gold.dim_zone;
DROP TABLE IF EXISTS la_lakehouse.gold.dim_date;
DROP TABLE IF EXISTS la_lakehouse.gold.dim_census_tract;
DROP TABLE IF EXISTS la_lakehouse.gold.dim_district;
DROP TABLE IF EXISTS la_lakehouse.gold.dim_area_planning_commision;
DROP TABLE IF EXISTS la_lakehouse.gold.dim_community_plan_area;
DROP TABLE IF EXISTS la_lakehouse.gold.dim_certified_neighborhood_council;
DROP TABLE IF EXISTS la_lakehouse.gold.dim_hillside_ordinance_area;
DROP TABLE IF EXISTS la_lakehouse.gold.dim_permit_type;   
DROP TABLE IF EXISTS la_lakehouse.gold.dim_use_type;

# %%
# %sql
CREATE OR REPLACE TABLE la_lakehouse.gold.dim_zone (
    zone_key BIGINT GENERATED BY DEFAULT AS IDENTITY PRIMARY KEY,
    zone STRING,
    zone_base STRING
)

# %%
# %sql
CREATE OR REPLACE TABLE la_lakehouse.gold.dim_date (
    date_key BIGINT GENERATED BY DEFAULT AS IDENTITY PRIMARY KEY,
    full_date DATE,
    year INTEGER,
    month INTEGER,
    day INTEGER,
    day_name STRING,
    day_of_week INTEGER,
    month_name STRING
)

# %%
# %sql
CREATE OR REPLACE TABLE la_lakehouse.gold.dim_census_tract (
    ct_key BIGINT GENERATED BY DEFAULT AS IDENTITY PRIMARY KEY,
    ct FLOAT
)

# %%
# %sql
CREATE OR REPLACE TABLE la_lakehouse.gold.dim_district (
    district_key BIGINT GENERATED BY DEFAULT AS IDENTITY PRIMARY KEY,
    cd INTEGER
)

# %%
# %sql
CREATE OR REPLACE TABLE la_lakehouse.gold.dim_area_planning_commision (
    apc_key BIGINT GENERATED BY DEFAULT AS IDENTITY PRIMARY KEY,
    apc STRING
)

# %%
# %sql
CREATE OR REPLACE TABLE la_lakehouse.gold.dim_community_plan_area (
    cpa_key BIGINT GENERATED BY DEFAULT AS IDENTITY PRIMARY KEY,
    cpa STRING
)

# %%
# %sql
CREATE OR REPLACE TABLE la_lakehouse.gold.dim_certified_neighborhood_council (
    cnc_key BIGINT GENERATED BY DEFAULT AS IDENTITY PRIMARY KEY,
    cnc STRING
)

# %%
# %sql
CREATE OR REPLACE TABLE la_lakehouse.gold.dim_hillside_ordinance_area (
    hl_key BIGINT GENERATED BY DEFAULT AS IDENTITY PRIMARY KEY,
    hl STRING
)

# %%
# %sql
CREATE OR REPLACE TABLE la_lakehouse.gold.dim_permit_type (
    permit_type_key BIGINT GENERATED BY DEFAULT AS IDENTITY PRIMARY KEY,
    permit_group STRING,
    permit_type STRING,
    permit_sub_type STRING,
    use_code INTEGER,
    use_desc STRING
)

# %%
# %sql
CREATE OR REPLACE TABLE la_lakehouse.gold.dim_use_type (
    use_type_key BIGINT GENERATED BY DEFAULT AS IDENTITY PRIMARY KEY,
    use_code INTEGER,
    use_desc STRING
)

# %% [markdown]
# #Testing tables

# %%
# %sql
SHOW TABLES IN la_lakehouse.gold
